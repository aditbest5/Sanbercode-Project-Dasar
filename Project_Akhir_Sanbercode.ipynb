# %% [markdown]
# # **Proyek Akhir - Aditya Aprianto**
# ## **Dataset**
# Dataset yang digunakan pada proyek kali ini adalah Data_Negara_HELP.csv. Berikut kolom yang ada pada data
#
# **Negara** : Nama negara
#
# **Kematian_anak**: Kematian anak di bawah usia 5 tahun per 1000 kelahiran
#
# **Ekspor** : Ekspor barang dan jasa perkapita
#
# **Kesehatan** : Total pengeluaran kesehatan perkapita
#
# **Impor** : Impor barang dan jasa perkapita
#
# **Pendapatan** : Penghasilan bersih perorang
#
# **Inflasi** :  Pengukuran tingkat pertumbuhan tahunan dari Total GDP
#
# **Harapan_hidup** : Jumlah tahun rata-rata seorang anak yang baru lahir akan hidup jika pola kematian saat ini tetap sama
#
# **Jumlah_fertiliti** : Jumlah anak yang akan lahir dari setiap wanita jika tingkat kesuburan usia saat ini tetap sama
#
# **GDPperkapita** : GDP per kapita. Dihitung sebagai Total GDP dibagi dengan total populasi.
#
#
# ## **Import Dataset**
#
# Hal pertama yang dilakukan adalah import dataset menggunakan library pandas. Lalu kita akan melihat datasetnya dengan memanggil variable data dan melihat 5 data pertama dengan memanggil head()

# %%
import pandas as pd

data = pd.read_csv("Data_Negara_HELP.csv")
data
# Out:
#                   Negara  Kematian_anak  ...  Jumlah_fertiliti  GDPperkapita
# 0            Afghanistan           90.2  ...              5.82           553
# 1                Albania           16.6  ...              1.65          4090
# 2                Algeria           27.3  ...              2.89          4460
# 3                 Angola          119.0  ...              6.16          3530
# 4    Antigua and Barbuda           10.3  ...              2.13         12200
# ..                   ...            ...  ...               ...           ...
# 162              Vanuatu           29.2  ...              3.50          2970
# 163            Venezuela           17.1  ...              2.47         13500
# 164              Vietnam           23.3  ...              1.95          1310
# 165                Yemen           56.3  ...              4.67          1310
# 166               Zambia           83.1  ...              5.40          1460
#
# [167 rows x 10 columns]

# %% [markdown]
# ## **Mengecek info pada data dan melihat tipe data**
#
# Hal selanjutnya kita akan melihat info pada dataset untuk mengetahui tipe data. Terdapat satu tipe object yaitu kolom Negara, 7 tipe data float, dan 2 tipe data int yaitu Pendapatan dan GDPperkapita.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Negara            167 non-null    object
#  1   Kematian_anak     167 non-null    float64
#  2   Ekspor            167 non-null    float64
#  3   Kesehatan         167 non-null    float64
#  4   Impor             167 non-null    float64
#  5   Pendapatan        167 non-null    int64
#  6   Inflasi           167 non-null    float64
#  7   Harapan_hidup     167 non-null    float64
#  8   Jumlah_fertiliti  167 non-null    float64
#  9   GDPperkapita      167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %% [markdown]
# ## **Deskripsi Statistika**
# Statistika deskriptif berkaitan dengan bagaimana kita menjelaskan dan murumuskan suatu data. Dengan menggunakan DataFrame.describe() kita akan melihat nilai statistika deskripsi yang berisi count, mean, std, min, Q1(25%), median (50%), Q3(75%), dan max.
#
# **count** : merupakan banyaknya anggota sampel di dalam sebuah kolom.
#
# **mean** : merupakan rata-rata sebuah kolom.
#
# **std** : merupakan nilai akar kuadrat dari varians (standard deviasi).
#
# **min** : merupakan nilai minimum / terkecil dari sebuah kolom.
#
# **Q1(25%)** : merupakan nilai tengah antara nilai terkecil dan median dari kolom.
#
# **median(50%)** : adalah median data yang menandai 50% data (membagi data menjadi dua).
#
# **Q3(75%)** : adalah nilai tengah antara median dan nilai tertinggi dari kelompok data.
#
# **max** : merupakan nilai maksimum / terbesar dari sebuah kolom.

# %%
data.describe()
# Out:
#        Kematian_anak      Ekspor  ...  Jumlah_fertiliti   GDPperkapita
# count     167.000000  167.000000  ...        167.000000     167.000000
# mean       38.270060   41.108976  ...          2.947964   12964.155689
# std        40.328931   27.412010  ...          1.513848   18328.704809
# min         2.600000    0.109000  ...          1.150000     231.000000
# 25%         8.250000   23.800000  ...          1.795000    1330.000000
# 50%        19.300000   35.000000  ...          2.410000    4660.000000
# 75%        62.100000   51.350000  ...          3.880000   14050.000000
# max       208.000000  200.000000  ...          7.490000  105000.000000
#
# [8 rows x 9 columns]

# %% [markdown]
# ## **Mengecek nilai kosong atau missing value**
#
# Missing value adalah hilangnya beberapa data yang telah diperoleh. Dalam dunia data science, missing value erat kaitannya dalam proses perselisihan data (data wrangling) sebelum nantinya akan dilakukan analisis dan prediksi data.
#
# Untuk mengecek nilai mising value kita dapat menggunakan syntax DataFrame.isnull(). Jika kita ingin mengetahui berapa total keseluruhan data yang hilang dapat ditambahkan .sum(). Karena tidak ada nilai missing value maka kita tidak perlu melakukan handling missing value.

# %%
data.isnull().sum()
# Out:
# Negara              0
# Kematian_anak       0
# Ekspor              0
# Kesehatan           0
# Impor               0
# Pendapatan          0
# Inflasi             0
# Harapan_hidup       0
# Jumlah_fertiliti    0
# GDPperkapita        0
# dtype: int64

# %% [markdown]
# ## **Mengecek nilai outlier dan handling outlier**
#
# Nilai outliers (atau yang biasa disebut dengan nilai pencilan) merupakan suatu nilai yang tidak normal. Dalam kata lain, nilai tersebut bernilai jauh sekali dari pusat data. Nilai pencilan ini dapat menyebabkan distorsi terhadap nilai yang asli. Dampaknya jika tidak serius menanggulangi nilai outliers akan berdampak pada ketidaksesuaian data analisa dan ketidakakuratan model machine learning yang dikerjakan nanti.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


sns.boxplot(x=data['Kematian_anak'])

# %%
sns.boxplot(x=data['Ekspor'])

# %%
sns.boxplot(x=data['Kesehatan'])

# %%
sns.boxplot(x=data['Impor'])

# %%
sns.boxplot(x=data['Pendapatan'])

# %% [markdown]
# Dapat dilihat banyak kolom yang terdapat outliernya. Untuk menghilangkan outlier dapat menggantinya dengan nilai IQR, mean, median, dan modus. Disini kita akan mengganti nilai outlier dengan nilai IQR

# %%
Q1 = data.quantile(0.25)
Q3 = data.quantile(0.75)
IQR=Q3-Q1
data=data[~((data<(Q1-1.5*IQR))|(data>(Q3+1.5*IQR))).any(axis=1)]
 
# Cek ukuran dataset setelah kita drop outliers
data.shape
# Out:
# (128, 10)

# %% [markdown]
# ## **Visualisasi Data**
# Disini kita akan melihat hubungan antar kolom data menggunakan heatmap seaborn. Dari hasil tersebut dapat dilihat bahwa GDPperkapita dengan Pendapatan memiliki korelasi yang kuat. Kita akan mengambil GDPperkapita dan pendapatan untuk dianalisis lebih lanjut.

# %%
plt.figure(figsize=(12,8))


sns.heatmap(data.corr(), annot=True, fmt='.2g');

# %% [markdown]
# # **Korelasi antara GDPperkapita dan Pendapatan**
# Dengan menggunakan scatterplot dan regplot kita dapat melihat hubungan kedua kolom tersebut. Dari hasil gambar dapat disimpulkan bahwa GDP perkapita dan pendapatan memiliki hubungan yang positif jika dilihat dari arah regresinya. Artinya peningkatan yang terjadi pada variabel GDPperkapita juga diikuti peningkatan pada variabel Pendapatan. Dan sebaliknya, jika variabel GDP perkapita mengalami penurunan maka variabel Pendapatan juga mengalami penurunan

# %%
sns.set_theme(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='GDPperkapita', y='Pendapatan', hue='Ekspor', size='Impor', sizes=(80, 120), palette='plasma')
sns.regplot(x="GDPperkapita", y="Pendapatan", data=data, scatter=False, color='black')
plt.xlabel('GDP per kapita')
plt.ylabel('Pendapatan')
# Out:
# Text(0, 0.5, 'Pendapatan')

# %%
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(60, 60))

for i in enumerate(data.describe().columns):
  plt.subplot(9,9, i[0]+1)
  sns.distplot(data[i[1]])
plt.show()

# %%
GDP = data.sort_values('GDPperkapita', ascending=False)
GDP
# Out:
#                Negara  Kematian_anak  ...  Jumlah_fertiliti  GDPperkapita
# 42             Cyprus            3.6  ...              1.42         30800
# 139             Spain            3.8  ...              1.37         30700
# 74             Israel            4.6  ...              3.03         30600
# 10            Bahamas           13.8  ...              1.86         28000
# 60             Greece            3.9  ...              1.48         26900
# ..                ...            ...  ...               ...           ...
# 106        Mozambique          101.0  ...              5.56           419
# 93         Madagascar           62.2  ...              4.60           413
# 37   Congo, Dem. Rep.          116.0  ...              6.54           334
# 88            Liberia           89.3  ...              5.02           327
# 26            Burundi           93.6  ...              6.26           231
#
# [128 rows x 10 columns]

# %%
plt.figure(figsize=(14,6))
plt.subplot(2,1,1)
sns.barplot(GDP.Negara.head(), GDP.GDPperkapita.head())
plt.title('Top Highest GDP')
plt.subplot(2,1,2)
sns.barplot(GDP.Negara.tail(), GDP.GDPperkapita.tail())
plt.title('Top lowest GDP')
plt.tight_layout()
plt.show()

# %%
Income = data.sort_values('Pendapatan', ascending=False)
Income
# Out:
#                Negara  Kematian_anak  ...  Jumlah_fertiliti  GDPperkapita
# 128      Saudi Arabia           15.7  ...              2.96         19300
# 115              Oman           11.7  ...              2.90         19300
# 11            Bahrain            8.6  ...              2.16         20700
# 42             Cyprus            3.6  ...              1.42         30800
# 139             Spain            3.8  ...              1.37         30700
# ..                ...            ...  ...               ...           ...
# 94             Malawi           90.5  ...              5.31           459
# 106        Mozambique          101.0  ...              5.56           419
# 26            Burundi           93.6  ...              6.26           231
# 88            Liberia           89.3  ...              5.02           327
# 37   Congo, Dem. Rep.          116.0  ...              6.54           334
#
# [128 rows x 10 columns]

# %%
plt.figure(figsize=(14,6))
plt.subplot(2,1,1)
sns.barplot(Income.Negara.head(), Income.Pendapatan.head())
plt.title('Top Highest Income')
plt.subplot(2,1,2)
sns.barplot(Income.Negara.tail(), Income.Pendapatan.tail())
plt.title('Top lowest Income')
plt.tight_layout()
plt.show()

# %%
new_data = data[['Pendapatan', 'GDPperkapita']]
new_data
# Out:
#      Pendapatan  GDPperkapita
# 0          1610           553
# 1          9930          4090
# 2         12900          4460
# 3          5900          3530
# 4         19100         12200
# ..          ...           ...
# 161        4240          1380
# 162        2950          2970
# 164        4490          1310
# 165        4480          1310
# 166        3280          1460
#
# [128 rows x 2 columns]

# %% [markdown]
# ## **Standarisasi menggunakan StandardScaler**

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# Standarisasi menggunakan StandardScaler
scaler = preprocessing.StandardScaler().fit(new_data)
new_data = scaler.transform(new_data)
new_data
# Out:
# array([[-0.97979661, -0.82556137],
#        [-0.12528564, -0.32838491],
#        [ 0.17975012, -0.27637607],
#        [-0.53918939, -0.407101  ],
#        [ 0.81652513,  0.81159278],
#        [ 0.77544287,  0.54452032],
#        [-0.45702488, -0.45067598],
#        [ 0.49813763, -0.08239712],
#        [ 1.20680658,  3.0325111 ],
#        [ 3.07604932,  2.00639061],
#        [-0.89455093, -0.79674566],
#        [ 0.42624367,  1.34573769],
#        [ 0.51867875, -0.05568988],
#        [-0.33583221, -0.2932438 ],
#        [-0.95822843, -0.79674566],
#        [-0.48578246, -0.59686301],
#        [-0.58951516, -0.6249759 ],
#        [-0.14685383, -0.2552914 ],
#        [ 0.22083238, -0.01070925],
#        [ 0.34407916,  0.67102833],
#        [ 0.42624367,  0.05816733],
#        [-0.99828363, -0.82246895],
#        [-1.06668559, -0.87082313],
#        [-0.88633447, -0.79280986],
#        [-0.87195568, -0.71915408],
#        [-0.54637879, -0.43802518],
#        [ 0.84733682,  0.9099879 ],
# ...

# %% [markdown]
# ## **Melakukan Clustering menggunakan K-Means dan Elbow Methods**
#
# Kita akan melakukan clustering menggunakan K-Means dan mencari nilai optimum cluster nya menggunakan Elbow Methods.
#
# Berikut hasilnya :

# %%
#Clustering dengan K-Means
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

kmeans1 = KMeans(n_clusters=2, random_state=42).fit(new_data)
labels1 = kmeans1.labels_

data_std = pd.DataFrame(data = new_data, columns = ['GDPperkapita', 'Pendapatan'])
data_std['label_kmeans1'] = labels1 

#Memvisualisasikan Hasil Clustering menggunakan scatterplot
plt.figure(figsize=(12,8))
plt.scatter(data_std.GDPperkapita[data_std.label_kmeans1 == 0], data_std['Pendapatan'][data_std.label_kmeans1 == 0], c='blue', s=100, edgecolor='green',linestyle='-')
plt.scatter(data_std.GDPperkapita[data_std.label_kmeans1 == 1], data_std['Pendapatan'][data_std.label_kmeans1 == 1], c='red', s=100, edgecolor='green',linestyle='-')

centers = kmeans1.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=500);
plt.xlabel('GDPperkapita')
plt.ylabel('Pendapatan')
plt.show()

# %%
wcss = []
for i in range(1, 11):
  kmeans = KMeans(n_clusters= i, init='k-means++', random_state = 42 )
  kmeans.fit(data_std)
  wcss.append(kmeans.inertia_)

plt.figure(figsize= (12, 8))
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#inisiasi ulang cluster
kmeans2 = KMeans(n_clusters=3, random_state=42).fit(new_data)

kmeans2.labels_
# Out:
# array([1, 1, 2, 1, 2, 2, 1, 2, 0, 0, 1, 2, 2, 1, 1, 1, 1, 1, 2, 2, 2, 1,
#        1, 1, 1, 1, 2, 1, 2, 1, 1, 1, 2, 1, 2, 0, 0, 2, 1, 1, 1, 1, 2, 1,
#        2, 1, 1, 1, 0, 2, 1, 1, 1, 1, 2, 1, 1, 2, 2, 0, 1, 1, 2, 1, 1, 1,
#        1, 2, 2, 1, 2, 2, 1, 1, 1, 2, 2, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 0,
#        1, 2, 1, 1, 1, 2, 0, 2, 2, 1, 1, 0, 1, 2, 0, 0, 1, 2, 0, 0, 1, 2,
#        1, 2, 1, 1, 2, 1, 1, 1, 2, 1, 1, 1, 2, 1, 1, 1, 1, 1], dtype=int32)

# %%
labels2 = kmeans2.labels_
data_std['label_kmeans2'] = labels2

#Memvisualisasikan hasil clustering
plt.figure(figsize=(12,8))
plt.scatter(data_std.GDPperkapita[data_std.label_kmeans2 == 0], data_std['Pendapatan'][data_std.label_kmeans2 == 0], c='yellow', s=100, edgecolor='green',linestyle='-')
plt.scatter(data_std.GDPperkapita[data_std.label_kmeans2 == 1], data_std['Pendapatan'][data_std.label_kmeans2 == 1], c='red', s=100, edgecolor='green',linestyle='-')
plt.scatter(data_std.GDPperkapita[data_std.label_kmeans2 == 2], data_std['Pendapatan'][data_std.label_kmeans2 == 2], c='blue', s=100, edgecolor='green',linestyle='-')

centers = kmeans2.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=500);
plt.xlabel('GDPperkapita')
plt.ylabel('Pendapatan')
plt.show()
